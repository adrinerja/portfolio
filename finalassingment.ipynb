# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter notebook on IBM Watson Studio

# %% [markdown]
# <b> Adrián Nerja </b>
# PhD in Economics

# %% [markdown]
# *I am interested in data science because I usually do research in theoretical economics, but I would like to include empirical investigation.*

# %% [markdown]
# ### In the next cell, we are going to compute how much would you have if you invest $10.000 at a compound rate of 5% during 15 years.

# %%
10000*(1+0.05)**15
# Out:
# 20789.28179411369

# %% [markdown]
# How to increase your money along time:
# * Improve the interest rate making better investment decisions.
# * Start to save and invest earlier.
# * ~~Be patient.~~
#
# When doing everything, you can see in the next picture how your money grows over time:

# %% [markdown]
# ![Captura.PNG](attachment:f82b3efc-e4cf-40a7-9e7e-fede2b7e098a.PNG)
